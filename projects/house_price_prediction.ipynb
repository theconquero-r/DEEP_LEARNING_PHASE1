# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import tensorflow 
from tensorflow import keras 
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import Dense, Dropout , BatchNormalization

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score,confusion_matrix, classification_report

#load dataset
from sklearn.datasets import fetch_california_housing
from tensorflow.keras.datasets import california_housing, boston_housing
(x_train, y_train), (x_test, y_test) = california_housing.load_data()

scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

x_train.shape
# Out:
# (16512, 8)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.628358006477356

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


callbacks=[EarlyStopping(
    monitor="val_loss",
    patience=25,
    restore_best_weights=True,
    mode="auto",
    verbose=1,
    
    ),
    ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=10,
    mode="auto",
    verbose=1,
    min_lr=1e-6
    )
]

# %%
model = Sequential()
model.add(Dense(128, activation="relu", input_shape=(x_train.shape[1],)))
model.add(Dense(64))
model.add(layers.Activation("relu"))

model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(1, activation="linear"))

# %%
from tensorflow.keras.optimizers import Adam
optimizer=Adam()

# %%
model.compile(optimizer=optimizer, loss="mse", metrics=["r2_score"])

# %%
model.fit(x_train, y_train, epochs=10000, batch_size=64, validation_split=0.2 , callbacks=callbacks)
# Out:
# Epoch 1/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 24080242688.0000 - r2_score: -0.8162 - val_loss: 5256093696.0000 - val_r2_score: 0.6126 - learning_rate: 0.0010
# Epoch 2/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4435906048.0000 - r2_score: 0.6654 - val_loss: 3936365056.0000 - val_r2_score: 0.7099 - learning_rate: 0.0010
# Epoch 3/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3900800000.0000 - r2_score: 0.7058 - val_loss: 3743762688.0000 - val_r2_score: 0.7241 - learning_rate: 0.0010
# Epoch 4/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3831878656.0000 - r2_score: 0.7110 - val_loss: 3797958144.0000 - val_r2_score: 0.7201 - learning_rate: 0.0010
# Epoch 5/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3688816640.0000 - r2_score: 0.7218 - val_loss: 3750975488.0000 - val_r2_score: 0.7235 - learning_rate: 0.0010
# Epoch 6/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3622495744.0000 - r2_score: 0.7268 - val_loss: 4152090880.0000 - val_r2_score: 0.6940 - learning_rate: 0.0010
# Epoch 7/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3575086080.0000 - r2_score: 0.7304 - val_loss: 4939469312.0000 - val_r2_score: 0.6359 - learning_rate: 0.0010
# Epoch 8/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3583255040.0000 - r2_score: 0.7297 - val_loss: 3526419200.0000 - val_r2_score: 0.7401 - learning_rate: 0.0010
# Epoch 9/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3372759808.0000 - r2_score: 0.7456 - val_loss: 3386029056.0000 - val_r2_score: 0.7504 - learning_rate: 0.0010
# Epoch 10/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3311078400.0000 - r2_score: 0.7503 - val_loss: 3690806528.0000 - val_r2_score: 0.7280 - learning_rate: 0.0010
# Epoch 11/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3414496512.0000 - r2_score: 0.7425 - val_loss: 4751927808.0000 - val_r2_score: 0.6498 - learning_rate: 0.0010
# Epoch 12/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3164462080.0000 - r2_score: 0.7613 - val_loss: 3190693888.0000 - val_r2_score: 0.7648 - learning_rate: 0.0010
# Epoch 13/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3204194560.0000 - r2_score: 0.7583 - val_loss: 4273405952.0000 - val_r2_score: 0.6850 - learning_rate: 0.0010
# Epoch 14/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3192108032.0000 - r2_score: 0.7592 - val_loss: 3863256320.0000 - val_r2_score: 0.7153 - learning_rate: 0.0010
# Epoch 15/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3013213184.0000 - r2_score: 0.7727 - val_loss: 3219189248.0000 - val_r2_score: 0.7627 - learning_rate: 0.0010
# Epoch 16/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3186122496.0000 - r2_score: 0.7597 - val_loss: 3082008320.0000 - val_r2_score: 0.7728 - learning_rate: 0.0010
# Epoch 17/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3130020608.0000 - r2_score: 0.7639 - val_loss: 3242347520.0000 - val_r2_score: 0.7610 - learning_rate: 0.0010
# Epoch 18/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2977142528.0000 - r2_score: 0.7755 - val_loss: 3576643328.0000 - val_r2_score: 0.7364 - learning_rate: 0.0010
# Epoch 19/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2983746816.0000 - r2_score: 0.7750 - val_loss: 3480215552.0000 - val_r2_score: 0.7435 - learning_rate: 0.0010
# Epoch 20/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3027383552.0000 - r2_score: 0.7717 - val_loss: 3138615552.0000 - val_r2_score: 0.7687 - learning_rate: 0.0010
# Epoch 21/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3078262016.0000 - r2_score: 0.7678 - val_loss: 3605830400.0000 - val_r2_score: 0.7342 - learning_rate: 0.0010
# Epoch 22/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2956073216.0000 - r2_score: 0.7770 - val_loss: 3034327552.0000 - val_r2_score: 0.7764 - learning_rate: 0.0010
# Epoch 23/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3082367744.0000 - r2_score: 0.7675 - val_loss: 3011404288.0000 - val_r2_score: 0.7780 - learning_rate: 0.0010
# Epoch 24/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2905721344.0000 - r2_score: 0.7808 - val_loss: 3097525760.0000 - val_r2_score: 0.7717 - learning_rate: 0.0010
# Epoch 25/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2847855616.0000 - r2_score: 0.7852 - val_loss: 3153392896.0000 - val_r2_score: 0.7676 - learning_rate: 0.0010
# Epoch 26/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2908166656.0000 - r2_score: 0.7807 - val_loss: 3426604544.0000 - val_r2_score: 0.7474 - learning_rate: 0.0010
# Epoch 27/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3073179392.0000 - r2_score: 0.7682 - val_loss: 3486862592.0000 - val_r2_score: 0.7430 - learning_rate: 0.0010
# Epoch 28/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2803642368.0000 - r2_score: 0.7885 - val_loss: 3086184192.0000 - val_r2_score: 0.7725 - learning_rate: 0.0010
# Epoch 29/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2919127296.0000 - r2_score: 0.7798 - val_loss: 3634092288.0000 - val_r2_score: 0.7321 - learning_rate: 0.0010
# Epoch 30/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2841069824.0000 - r2_score: 0.7857 - val_loss: 3624017664.0000 - val_r2_score: 0.7329 - learning_rate: 0.0010
# Epoch 31/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2803428096.0000 - r2_score: 0.7886 - val_loss: 2883806464.0000 - val_r2_score: 0.7874 - learning_rate: 0.0010
# Epoch 32/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2829548544.0000 - r2_score: 0.7866 - val_loss: 3522296576.0000 - val_r2_score: 0.7404 - learning_rate: 0.0010
# Epoch 33/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2793569792.0000 - r2_score: 0.7893 - val_loss: 3462978048.0000 - val_r2_score: 0.7448 - learning_rate: 0.0010
# Epoch 34/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2672923392.0000 - r2_score: 0.7984 - val_loss: 2943992576.0000 - val_r2_score: 0.7830 - learning_rate: 0.0010
# Epoch 35/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2699585024.0000 - r2_score: 0.7964 - val_loss: 3115471360.0000 - val_r2_score: 0.7704 - learning_rate: 0.0010
# Epoch 36/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2790233344.0000 - r2_score: 0.7896 - val_loss: 3053894912.0000 - val_r2_score: 0.7749 - learning_rate: 0.0010
# Epoch 37/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2647394816.0000 - r2_score: 0.8003 - val_loss: 3085365760.0000 - val_r2_score: 0.7726 - learning_rate: 0.0010
# Epoch 38/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2738522624.0000 - r2_score: 0.7935 - val_loss: 2831695104.0000 - val_r2_score: 0.7913 - learning_rate: 0.0010
# Epoch 39/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2676484096.0000 - r2_score: 0.7981 - val_loss: 3068073728.0000 - val_r2_score: 0.7739 - learning_rate: 0.0010
# Epoch 40/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2731949824.0000 - r2_score: 0.7940 - val_loss: 2985810688.0000 - val_r2_score: 0.7799 - learning_rate: 0.0010
# Epoch 41/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2717628416.0000 - r2_score: 0.7950 - val_loss: 3080613376.0000 - val_r2_score: 0.7729 - learning_rate: 0.0010
# Epoch 42/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2648645888.0000 - r2_score: 0.8002 - val_loss: 3168740864.0000 - val_r2_score: 0.7664 - learning_rate: 0.0010
# Epoch 43/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2636294912.0000 - r2_score: 0.8012 - val_loss: 2907437824.0000 - val_r2_score: 0.7857 - learning_rate: 0.0010
# Epoch 44/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2597714432.0000 - r2_score: 0.8041 - val_loss: 3857214976.0000 - val_r2_score: 0.7157 - learning_rate: 0.0010
# Epoch 45/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2843229184.0000 - r2_score: 0.7856 - val_loss: 3099414272.0000 - val_r2_score: 0.7716 - learning_rate: 0.0010
# Epoch 46/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2614274560.0000 - r2_score: 0.8028 - val_loss: 3300281088.0000 - val_r2_score: 0.7567 - learning_rate: 0.0010
# Epoch 47/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2789364224.0000 - r2_score: 0.7896 - val_loss: 2973681920.0000 - val_r2_score: 0.7808 - learning_rate: 0.0010
# Epoch 48/10000
# 199/207 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2556241321.8090 - r2_score: 0.8056
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2547565824.0000 - r2_score: 0.8079 - val_loss: 3523081984.0000 - val_r2_score: 0.7403 - learning_rate: 0.0010
# Epoch 49/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2371535872.0000 - r2_score: 0.8211 - val_loss: 2825812736.0000 - val_r2_score: 0.7917 - learning_rate: 5.0000e-04
# Epoch 50/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2340957696.0000 - r2_score: 0.8234 - val_loss: 2841233920.0000 - val_r2_score: 0.7906 - learning_rate: 5.0000e-04
# Epoch 51/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2435397888.0000 - r2_score: 0.8163 - val_loss: 2906123264.0000 - val_r2_score: 0.7858 - learning_rate: 5.0000e-04
# Epoch 52/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2335496448.0000 - r2_score: 0.8239 - val_loss: 2907572992.0000 - val_r2_score: 0.7857 - learning_rate: 5.0000e-04
# Epoch 53/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2317877248.0000 - r2_score: 0.8252 - val_loss: 2772742656.0000 - val_r2_score: 0.7956 - learning_rate: 5.0000e-04
# Epoch 54/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2301710080.0000 - r2_score: 0.8264 - val_loss: 2787139328.0000 - val_r2_score: 0.7946 - learning_rate: 5.0000e-04
# Epoch 55/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2347056896.0000 - r2_score: 0.8230 - val_loss: 2787935744.0000 - val_r2_score: 0.7945 - learning_rate: 5.0000e-04
# Epoch 56/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2373733632.0000 - r2_score: 0.8210 - val_loss: 2727425024.0000 - val_r2_score: 0.7990 - learning_rate: 5.0000e-04
# Epoch 57/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2286758912.0000 - r2_score: 0.8275 - val_loss: 2856199168.0000 - val_r2_score: 0.7895 - learning_rate: 5.0000e-04
# Epoch 58/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2291592960.0000 - r2_score: 0.8272 - val_loss: 2797329408.0000 - val_r2_score: 0.7938 - learning_rate: 5.0000e-04
# Epoch 59/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2263007744.0000 - r2_score: 0.8293 - val_loss: 2820718592.0000 - val_r2_score: 0.7921 - learning_rate: 5.0000e-04
# Epoch 60/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2264175872.0000 - r2_score: 0.8292 - val_loss: 2989040896.0000 - val_r2_score: 0.7797 - learning_rate: 5.0000e-04
# Epoch 61/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2237982720.0000 - r2_score: 0.8312 - val_loss: 3096464640.0000 - val_r2_score: 0.7718 - learning_rate: 5.0000e-04
# Epoch 62/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2227998720.0000 - r2_score: 0.8320 - val_loss: 2745774080.0000 - val_r2_score: 0.7976 - learning_rate: 5.0000e-04
# Epoch 63/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2257477120.0000 - r2_score: 0.8297 - val_loss: 2823612416.0000 - val_r2_score: 0.7919 - learning_rate: 5.0000e-04
# Epoch 64/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2248576512.0000 - r2_score: 0.8304 - val_loss: 2979451392.0000 - val_r2_score: 0.7804 - learning_rate: 5.0000e-04
# Epoch 65/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2234122496.0000 - r2_score: 0.8315 - val_loss: 2792313088.0000 - val_r2_score: 0.7942 - learning_rate: 5.0000e-04
# Epoch 66/10000
# 191/207 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2169439306.3874 - r2_score: 0.8392
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2203324928.0000 - r2_score: 0.8338 - val_loss: 3054764032.0000 - val_r2_score: 0.7748 - learning_rate: 5.0000e-04
# Epoch 67/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2081919488.0000 - r2_score: 0.8430 - val_loss: 2704784128.0000 - val_r2_score: 0.8006 - learning_rate: 2.5000e-04
# Epoch 68/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2066917760.0000 - r2_score: 0.8441 - val_loss: 2878814720.0000 - val_r2_score: 0.7878 - learning_rate: 2.5000e-04
# Epoch 69/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2057282944.0000 - r2_score: 0.8448 - val_loss: 2678961408.0000 - val_r2_score: 0.8025 - learning_rate: 2.5000e-04
# Epoch 70/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2066075136.0000 - r2_score: 0.8442 - val_loss: 2719974400.0000 - val_r2_score: 0.7995 - learning_rate: 2.5000e-04
# Epoch 71/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2067914880.0000 - r2_score: 0.8440 - val_loss: 2962339840.0000 - val_r2_score: 0.7817 - learning_rate: 2.5000e-04
# Epoch 72/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2058342400.0000 - r2_score: 0.8448 - val_loss: 2701179136.0000 - val_r2_score: 0.8009 - learning_rate: 2.5000e-04
# Epoch 73/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2049223296.0000 - r2_score: 0.8454 - val_loss: 2726848000.0000 - val_r2_score: 0.7990 - learning_rate: 2.5000e-04
# Epoch 74/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2074979584.0000 - r2_score: 0.8435 - val_loss: 2672941824.0000 - val_r2_score: 0.8030 - learning_rate: 2.5000e-04
# Epoch 75/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2055911040.0000 - r2_score: 0.8449 - val_loss: 2654598912.0000 - val_r2_score: 0.8043 - learning_rate: 2.5000e-04
# Epoch 76/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2034290176.0000 - r2_score: 0.8466 - val_loss: 2733881856.0000 - val_r2_score: 0.7985 - learning_rate: 2.5000e-04
# Epoch 77/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2024281600.0000 - r2_score: 0.8473 - val_loss: 2743386368.0000 - val_r2_score: 0.7978 - learning_rate: 2.5000e-04
# Epoch 78/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2044296704.0000 - r2_score: 0.8458 - val_loss: 2846884864.0000 - val_r2_score: 0.7902 - learning_rate: 2.5000e-04
# Epoch 79/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2018939648.0000 - r2_score: 0.8477 - val_loss: 2836130048.0000 - val_r2_score: 0.7910 - learning_rate: 2.5000e-04
# Epoch 80/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2006952832.0000 - r2_score: 0.8486 - val_loss: 2746875392.0000 - val_r2_score: 0.7975 - learning_rate: 2.5000e-04
# Epoch 81/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1987677824.0000 - r2_score: 0.8501 - val_loss: 2724102656.0000 - val_r2_score: 0.7992 - learning_rate: 2.5000e-04
# Epoch 82/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2027823104.0000 - r2_score: 0.8471 - val_loss: 2786058752.0000 - val_r2_score: 0.7947 - learning_rate: 2.5000e-04
# Epoch 83/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1968542976.0000 - r2_score: 0.8515 - val_loss: 2761656832.0000 - val_r2_score: 0.7964 - learning_rate: 2.5000e-04
# Epoch 84/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1985669632.0000 - r2_score: 0.8502 - val_loss: 2684197120.0000 - val_r2_score: 0.8022 - learning_rate: 2.5000e-04
# Epoch 85/10000
# 191/207 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1959325398.4503 - r2_score: 0.8525
# Epoch 85: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1959870848.0000 - r2_score: 0.8522 - val_loss: 2717404928.0000 - val_r2_score: 0.7997 - learning_rate: 2.5000e-04
# Epoch 86/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1921913984.0000 - r2_score: 0.8550 - val_loss: 2792320000.0000 - val_r2_score: 0.7942 - learning_rate: 1.2500e-04
# Epoch 87/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1904403840.0000 - r2_score: 0.8564 - val_loss: 2726220544.0000 - val_r2_score: 0.7991 - learning_rate: 1.2500e-04
# Epoch 88/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1909337600.0000 - r2_score: 0.8560 - val_loss: 2750376448.0000 - val_r2_score: 0.7973 - learning_rate: 1.2500e-04
# Epoch 89/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1884472960.0000 - r2_score: 0.8579 - val_loss: 2725704960.0000 - val_r2_score: 0.7991 - learning_rate: 1.2500e-04
# Epoch 90/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1891495680.0000 - r2_score: 0.8573 - val_loss: 2811071232.0000 - val_r2_score: 0.7928 - learning_rate: 1.2500e-04
# Epoch 91/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1897710720.0000 - r2_score: 0.8569 - val_loss: 2684215808.0000 - val_r2_score: 0.8022 - learning_rate: 1.2500e-04
# Epoch 92/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1899506304.0000 - r2_score: 0.8567 - val_loss: 2719484928.0000 - val_r2_score: 0.7996 - learning_rate: 1.2500e-04
# Epoch 93/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1875304960.0000 - r2_score: 0.8586 - val_loss: 2746028544.0000 - val_r2_score: 0.7976 - learning_rate: 1.2500e-04
# Epoch 94/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1887909760.0000 - r2_score: 0.8576 - val_loss: 2955688192.0000 - val_r2_score: 0.7821 - learning_rate: 1.2500e-04
# Epoch 95/10000
# 202/207 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1826320939.7228 - r2_score: 0.8630
# Epoch 95: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1894770688.0000 - r2_score: 0.8571 - val_loss: 2698729216.0000 - val_r2_score: 0.8011 - learning_rate: 1.2500e-04
# Epoch 96/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1843568256.0000 - r2_score: 0.8610 - val_loss: 2699525120.0000 - val_r2_score: 0.8010 - learning_rate: 6.2500e-05
# Epoch 97/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1836871296.0000 - r2_score: 0.8615 - val_loss: 2701699328.0000 - val_r2_score: 0.8009 - learning_rate: 6.2500e-05
# Epoch 98/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1835048448.0000 - r2_score: 0.8616 - val_loss: 2748391680.0000 - val_r2_score: 0.7974 - learning_rate: 6.2500e-05
# Epoch 99/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1837699712.0000 - r2_score: 0.8614 - val_loss: 2752805376.0000 - val_r2_score: 0.7971 - learning_rate: 6.2500e-05
# Epoch 100/10000
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1828767232.0000 - r2_score: 0.8621 - val_loss: 2741606912.0000 - val_r2_score: 0.7979 - learning_rate: 6.2500e-05
# Epoch 100: early stopping
# Restoring model weights from the end of the best epoch: 75.

# %%
y_pred = model.predict(x_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
print("r2_score : ", r2_score(y_test, y_pred))
# Out:
# r2_score :  0.7948753833770752
