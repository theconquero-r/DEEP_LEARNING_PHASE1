# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("Datasets/placement.csv")
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x=df["resume_score"],y=df["cgpa"],hue=df["placed"])
# Out:
# <Axes: xlabel='resume_score', ylabel='cgpa'>

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
model=Perceptron()
model.fit(x,y)
# Out:
# Perceptron()

# %%
model.coef_
# model.intercept_
# Out:
# array([[ 40.26, -36.  ]])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.values,y.values,clf=model, legend=1)
# Out:
# /home/karan/miniconda3/envs/tf_gpu/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
